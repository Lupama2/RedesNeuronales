# %% [markdown]
# ### Ejercicio 4

# %%
#Import libraries
import numpy as np
from scipy.integrate import solve_ivp
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt

# %%
#Defino ctes


C_hat = 1 #[mS]
g_K_adim = 36
g_Na_adim = 120
g_L_adim = 0.3

V_K = -77 #[mV]
V_Na = 50 #[mV]
V_L = -54.4 #[mV]


#Defino funciones
def m_inf(V):

    a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
    b_m = 4*np.exp(-(V + 65)/18)

    return a_m/(a_m + b_m)

def h_inf(V):
        
    a_h = 0.07*np.exp(-(V + 65)/20)
    b_h = 1/(1 + np.exp(-(V + 35)/10))

    return a_h/(a_h + b_h)

def n_inf(V):
    
    a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
    b_n = 0.125*np.exp(-(V + 65)/80)

    return a_n/(a_n + b_n)

def tau_m(V):
        
    a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
    b_m = 4*np.exp(-(V + 65)/18)

    return 1/(a_m + b_m)

def tau_h(V):

    a_h = 0.07*np.exp(-(V + 65)/20)
    b_h = 1/(1 + np.exp(-(V + 35)/10))

    return 1/(a_h + b_h)

def tau_n(V):
    
    a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
    b_n = 0.125*np.exp(-(V + 65)/80)

    return 1/(a_n + b_n)

# %%
#Grafico m_inf(V), h_inf(V) y n_inf(V)

V = np.linspace(-100, 100, 1000)

plt.figure(figsize=(10, 5))

plt.subplot(1, 3, 1)
plt.plot(V, m_inf(V), color='tab:red')
#Añado una línea vertical en V = V_Na
plt.axvline(x=V_Na, color='tab:orange', linestyle='--')
plt.xlabel('V [mV]')
plt.ylabel('m_inf')
plt.grid()

plt.subplot(1, 3, 2)
plt.plot(V, h_inf(V), color='tab:green')
#Añado una línea vertical en V = V_Na
plt.axvline(x=V_Na, color='tab:orange', linestyle='--')
plt.xlabel('V [mV]')
plt.ylabel('h_inf')
plt.grid()

plt.subplot(1, 3, 3)
plt.plot(V, n_inf(V), color='tab:blue')
#Añado una línea vertical en V = V_K
plt.axvline(x=V_K, color='tab:orange', linestyle='--')
plt.xlabel('V [mV]')
plt.ylabel('n_inf')
plt.grid()

# %%
#Defino derivada

def derivada(t, y, I_ext):
    '''
    
    

    C_hat = C / g_hat : [ms = mili segundos]
    I_ext : [muA/cm2]
    V: [mV]
    
    Derivada
    y[0]: V
    y[1]: m
    y[2]: h
    y[3]: n
    
    '''

    #Def derivative vector
    dydt = np.empty(4)

    #Asigno variables
    V = y[0]; m = y[1]; h = y[2]; n = y[3]

    #Eq of charge conservation
    dydt[0] = (1/C_hat) *(I_ext - g_K_adim*n**4*(V - V_K) - g_Na_adim*m**3*h*(V - V_Na) - g_L_adim*(V - V_L))

    #Eq's m, h, n
    dydt[1] = (m_inf(V) - m)/tau_m(V)
    dydt[2] = (h_inf(V) - h)/tau_h(V)
    dydt[3] = (n_inf(V) - n)/tau_n(V)


    return dydt

# %%
#Condiciones iniciales
V0 = -77
y0_vec = np.array([V0, m_inf(V0), h_inf(V0), n_inf(V0)])

# %%
#Resuelvo numéricamente


t_ini = 0
t_fin = 250 #[ms]

I_ext = 12

soln = solve_ivp(derivada, [t_ini, t_fin], y0_vec, method = "RK45", args = (I_ext,))
# Out:
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:17: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:18: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:38: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:39: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\3530957316.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   dydt[1] = (m_inf(V) - m)/tau_m(V)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:24: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:25: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   return a_h/(a_h + b_h)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:45: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:46: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:31: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:52: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))

# %%
#Grafico

fig, ax = plt.subplots(4, 1, figsize = (8, 8), sharex = True)

ax[0].plot(soln.t, soln.y[0], color = "tab:blue")
ax[0].set_ylabel("V [mV]")

ax[1].plot(soln.t, soln.y[3], color = "tab:red")
ax[1].set_ylabel("n")

ax[2].plot(soln.t, soln.y[1], color = "tab:orange")
ax[2].set_ylabel("m")

ax[3].plot(soln.t, soln.y[2], color = "tab:green")
ax[3].set_ylabel("h")



ax[3].set_xlabel("t [ms]")
plt.show()

# %%
# error

# %%
def solve_and_plot(I_ext):
    t_ini = 0
    t_fin = 100 #[ms]
    
    soln = solve_ivp(derivada, [t_ini, t_fin], y0_vec, method="RK45", args=(I_ext,))
    plt.plot(soln.t, soln.y[0])
    plt.ylabel("V (mV)")
    plt.xlabel("t (ms)")
    plt.ylim([-100,50])
    plt.show()
    

# Widget interactivo
widgets.interact(solve_and_plot, I_ext=widgets.FloatSlider(min=0, max=20, step=0.1, value=5))
# Out:
# interactive(children=(FloatSlider(value=5.0, description='I_ext', max=20.0), Output()), _dom_classes=('widget-…
# <function __main__.solve_and_plot(I_ext)>

# %%
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\lupam\OneDrive\Escritorio\GitHub\RedesNeuronales\Practicas\practica_1\ejercicio_4_potencial_de_accion.ipynb Celda 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> error
#
# NameError: name 'error' is not defined

# %%
#Determino la frecuencia de los pulsos presentes en V(t) y grafico el espectro de frecuencias

#Importo las librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

#Defino la función que cuenta el número de picos que tiene el voltaje en función del tiempo
def frec_pulsos(t_vec, V_vec):
    '''
    
    Debería dejar pasar algunos pasos
    '''
    umbral = 10

    n = 0
    for i in range(len(V_vec)):
        if V_vec[i]>umbral and pico == False:
            n += 1
            pico = True
            continue
        if V_vec[i]<umbral:
            pico = False
            continue

    return n/(t_vec[-1]-t_vec[0])




#Defino la función que calcula la frecuencia de pulsos en función de I_ext
def frec_pulsos_I(I_ext):

    #Resuelvo el sistema de ecuaciones
    t_ini = 0
    t_fin = 1000 #[ms]
    soln = solve_ivp(derivada, [t_ini, t_fin], y0_vec, method="RK45", args=(I_ext,));

    t = soln.t
    V = soln.y[0]

    #Calculo la frecuencia de pulsos
    frec = frec_pulsos(t,V)

    return frec

# %%
frec_pulsos_I(14)
# Out:
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:17: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:18: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:38: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:39: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\3530957316.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   dydt[1] = (m_inf(V) - m)/tau_m(V)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:24: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:25: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   return a_h/(a_h + b_h)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:45: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:46: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:31: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:32: RuntimeWarning: overflow encountered in exp
#   b_n = 0.125*np.exp(-(V + 65)/80)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:52: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:53: RuntimeWarning: overflow encountered in exp
#   b_n = 0.125*np.exp(-(V + 65)/80)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\3530957316.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   dydt[3] = (n_inf(V) - n)/tau_n(V)
# 0.073

# %%
#Calculo la frecuencia para distintos valores de corriente
I_ext_vec = np.linspace(0,14, num = 40)
frec_vec = np.empty(len(I_ext_vec))

for i in range(len(I_ext_vec)):
    frec_vec[i] = frec_pulsos_I(I_ext_vec[i])
    print("Porcentaje de cálculo: ", i/len(I_ext_vec)*100, " %")
# Out:
# Porcentaje de cálculo:  0.0  %
# Porcentaje de cálculo:  2.5  %
# Porcentaje de cálculo:  5.0  %
# Porcentaje de cálculo:  7.5  %
# Porcentaje de cálculo:  10.0  %
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:17: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:18: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:38: RuntimeWarning: overflow encountered in exp
#   a_m = 0.1*(V + 40)/(1 - np.exp(-(V + 40)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:39: RuntimeWarning: overflow encountered in exp
#   b_m = 4*np.exp(-(V + 65)/18)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\3530957316.py:30: RuntimeWarning: divide by zero encountered in scalar divide
#   dydt[1] = (m_inf(V) - m)/tau_m(V)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:24: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:25: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:27: RuntimeWarning: invalid value encountered in scalar divide
#   return a_h/(a_h + b_h)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:45: RuntimeWarning: overflow encountered in exp
#   a_h = 0.07*np.exp(-(V + 65)/20)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:46: RuntimeWarning: overflow encountered in exp
#   b_h = 1/(1 + np.exp(-(V + 35)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:31: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:32: RuntimeWarning: overflow encountered in exp
#   b_n = 0.125*np.exp(-(V + 65)/80)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:52: RuntimeWarning: overflow encountered in exp
#   a_n = 0.01*(V + 55)/(1 - np.exp(-(V + 55)/10))
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\406138121.py:53: RuntimeWarning: overflow encountered in exp
#   b_n = 0.125*np.exp(-(V + 65)/80)
# C:\Users\lupam\AppData\Local\Temp\ipykernel_25476\3530957316.py:32: RuntimeWarning: divide by zero encountered in scalar divide
#   dydt[3] = (n_inf(V) - n)/tau_n(V)
# Porcentaje de cálculo:  12.5  %
# Porcentaje de cálculo:  15.0  %
# Porcentaje de cálculo:  17.5  %
# Porcentaje de cálculo:  20.0  %
# Porcentaje de cálculo:  22.5  %
# Porcentaje de cálculo:  25.0  %
# Porcentaje de cálculo:  27.500000000000004  %
# Porcentaje de cálculo:  30.0  %
# Porcentaje de cálculo:  32.5  %
# Porcentaje de cálculo:  35.0  %
# Porcentaje de cálculo:  37.5  %
# Porcentaje de cálculo:  40.0  %
# Porcentaje de cálculo:  42.5  %
# Porcentaje de cálculo:  45.0  %
# Porcentaje de cálculo:  47.5  %
# Porcentaje de cálculo:  50.0  %
# Porcentaje de cálculo:  52.5  %
# Porcentaje de cálculo:  55.00000000000001  %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\lupam\OneDrive\Escritorio\GitHub\RedesNeuronales\Practicas\practica_1\ejercicio_4_potencial_de_accion.ipynb Celda 14 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> frec_vec = np.empty(len(I_ext_vec))
#       <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> for i in range(len(I_ext_vec)):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     frec_vec[i] = frec_pulsos_I(I_ext_vec[i])
#       <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     print("Porcentaje de cálculo: ", i/len(I_ext_vec)*100, " %")
#
# c:\Users\lupam\OneDrive\Escritorio\GitHub\RedesNeuronales\Practicas\practica_1\ejercicio_4_potencial_de_accion.ipynb Celda 14 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=34'>35</a> t_ini = 0
#      <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=35'>36</a> t_fin = 1000 #[ms]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=36'>37</a> soln = solve_ivp(derivada, [t_ini, t_fin], y0_vec, method="RK45", args=(I_ext,));
#      <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=38'>39</a> t = soln.t
#      <a href='vscode-notebook-cell:/c%3A/Users/lupam/OneDrive/Escritorio/GitHub/RedesNeuronales/Practicas/practica_1/ejercicio_4_potencial_de_accion.ipynb#X15sZmlsZQ%3D%3D?line=39'>40</a> V = soln.y[0]
#
# File c:\ProgramData\Anaconda3\envs\Maestria3\Lib\site-packages\scipy\integrate\_ivp\ivp.py:591, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     589 status = None
#     590 while status is None:
# --> 591     message = solver.step()
#     593     if solver.status == 'finished':
#     594         status = 0
#
# File c:\ProgramData\Anaconda3\envs\Maestria3\Lib\site-packages\scipy\integrate\_ivp\base.py:181, in OdeSolver.step(self)
#     179 else:
#     180     t = self.t
# --> 181     success, message = self._step_impl()
#     183     if not success:
#     184         self.status = 'failed'
#
# File c:\ProgramData\Anaconda3\envs\Maestria3\Lib\site-packages\scipy\integrate\_ivp\rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File c:\ProgramData\Anaconda3\envs\Maestria3\Lib\site-packages\scipy\integrate\_ivp\rk.py:66, in rk_step(fun, t, y, f, h, A, B, C, K)
#      63     dy = np.dot(K[:s].T, a[:s]) * h
#      64     K[s] = fun(t + c * h, y + dy)
# ---> 66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#      69 K[-1] = f_new
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
#Grafico
plt.plot(I_ext_vec, frec_vec, "-o")
plt.ylabel("f [1/s]")
plt.xlabel("I_ext [mA]")
# Out:
# Text(0.5, 0, 'I_ext [mA]')
